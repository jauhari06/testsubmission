# %% [markdown]
# # Proyek Analisis Data: [order_payments_dataset , products_dataset]
# - **Nama:** Jundi Jauhari Habib
# - **Email:** Jundihabib94@gmail.com
# - **ID Dicoding:** jundi_jauhari_habib

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Apa jenis pembayaran yang paling umum digunakan oleh pelanggan?
# - Apa kategori produk yang paling umum terjual?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
order_payment_df = pd.read_csv("https://raw.githubusercontent.com/jauhari06/E-commerce-public-dataset/main/order_payments_dataset.csv")
order_payment_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
products_df = pd.read_csv("https://raw.githubusercontent.com/jauhari06/E-commerce-public-dataset/main/products_dataset.csv")
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %% [markdown]
# ### Assessing Data

# %%
Assessing data order payment

# %%
order_payment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
order_payment_df.nunique()
# Out:
# order_id                99440
# payment_sequential         29
# payment_type                5
# payment_installments       24
# payment_value           29077
# dtype: int64

# %%
print("Jumlah duplikasi: ",order_payment_df.duplicated().sum())
order_payment_df.describe()
# Out:
# Jumlah duplikasi:  0
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %%
Assessing data product

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
products_df.nunique()
# Out:
# product_id                    32951
# product_category_name            73
# product_name_lenght              66
# product_description_lenght     2960
# product_photos_qty               19
# product_weight_g               2204
# product_length_cm                99
# product_height_cm               102
# product_width_cm                 95
# dtype: int64

# %%
print("Jumlah duplikasi: ", products_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
products_df.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %% [markdown]
# ### Cleaning Data

# %%
cleaning data order payment

# %%
order_payment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
cleaning data product

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
products_df.product_category_name.value_counts()
# Out:
# product_category_name
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: count, Length: 73, dtype: int64

# %%
products_df['product_category_name'] = products_df['product_category_name'].fillna(products_df['product_category_name'].mode()[0])

# %%
products_df['product_description_lenght'] = products_df['product_description_lenght'].fillna(products_df['product_description_lenght'].mean())

# %%
products_df['product_name_lenght'] = products_df['product_name_lenght'].fillna(products_df['product_name_lenght'].mode()[0])

# %%
products_df['product_photos_qty'] = products_df['product_photos_qty'].fillna(products_df['product_photos_qty'].mode()[0])

# %%
for col in ['product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm']:
    products_df[col] = products_df[col].fillna(products_df[col].median())

# %%
products_df.isnull().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32951 non-null  object
#  2   product_name_lenght         32951 non-null  float64
#  3   product_description_lenght  32951 non-null  float64
#  4   product_photos_qty          32951 non-null  float64
#  5   product_weight_g            32951 non-null  float64
#  6   product_length_cm           32951 non-null  float64
#  7   product_height_cm           32951 non-null  float64
#  8   product_width_cm            32951 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
Data order

# %%
order_payment_df.sample(5)
# Out:
#                                order_id  payment_sequential payment_type  \
# 80640  21068b8eb0d85fa340b2cfaecaec42a8                   1  credit_card
# 55981  10b2031a821c35b0cf0c9ff505eaa456                   1  credit_card
# 48682  c84b66bfc6edd6b56325d5342ec421a0                   1  credit_card
# 90420  65c3a33271e3070af95cc3c03018871d                   1  credit_card
# 50705  14feb2791a33105fe2092f7ac34e3200                   1  credit_card
#
#        payment_installments  payment_value
# 80640                     1         231.37
# 55981                     1         213.55
# 48682                     3          35.77
# 90420                     1          36.69
# 50705                     8          93.91

# %%
order_payment_df.describe(include="all")
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            5
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# ...

# %%
order_payment_df.order_id.is_unique
# Out:
# False

# %%
order_payment_df.order_id.duplicated
# Out:
# <bound method Series.duplicated of 0         b81ef226f3fe1789b1e8b2acac839d17
# 1         a9810da82917af2d9aefd1278f1dcfa0
# 2         25e8ea4e93396b6fa0d3dd708e76c1bd
# 3         ba78997921bbcdc1373bb41e913ab953
# 4         42fdf880ba16b47b59251dd489d4441a
#                         ...
# 103881    0406037ad97740d563a178ecc7a2075c
# 103882    7b905861d7c825891d6347454ea7863f
# 103883    32609bbb3dd69b3c066a6860554a77bf
# 103884    b8b61059626efa996a60be9bb9320e10
# 103885    28bbae6599b09d39ca406b747b6632b1
# Name: order_id, Length: 103886, dtype: object>

# %%
order_payment_df.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %%
Data product

# %%
products_df.sample(5)
# Out:
#                              product_id   product_category_name  \
# 18866  15c30c08ae39469fbf52befff9569adb             eletronicos
# 1579   cf40e5e0674c8f74da58b2620de88ccc      relogios_presentes
# 256    302a19dacdbb5ed2f74f9dee8126ef79                   bebes
# 7225   b4693721011686a49e4b8fac4e527dde        moveis_decoracao
# 7563   9b20cbe99cd2a76d917fd7c13cc75384  informatica_acessorios
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 18866                 29.0                       247.0                 1.0
# 1579                  60.0                       286.0                 4.0
# 256                   64.0                       882.0                 5.0
# 7225                  42.0                       789.0                 1.0
# 7563                  52.0                       944.0                 1.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 18866             490.0               18.0               11.0
# ...

# %%
products_df.describe(include="all")
# Out:
#                               product_id product_category_name  \
# count                              32951                 32951
# unique                             32951                    73
# top     1e9e8ef04dbcff4541ed26657ea517e5       cama_mesa_banho
# freq                                   1                  3639
# mean                                 NaN                   NaN
# std                                  NaN                   NaN
# min                                  NaN                   NaN
# 25%                                  NaN                   NaN
# 50%                                  NaN                   NaN
# 75%                                  NaN                   NaN
# max                                  NaN                   NaN
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# count          32951.000000                32951.000000        32951.000000
# ...

# %%
products_df.product_id.is_unique
# Out:
# True

# %%
products_df.product_id.duplicated
# Out:
# <bound method Series.duplicated of 0        1e9e8ef04dbcff4541ed26657ea517e5
# 1        3aa071139cb16b67ca9e5dea641aaa2f
# 2        96bd76ec8810374ed1b65e291975717f
# 3        cef67bcfe19066a932b7673e239eb23d
# 4        9dc1a7de274444849c219cff195d0b71
#                        ...
# 32946    a0b7d5a992ccda646f2d34e418fff5a0
# 32947    bf4538d88321d0fd4412a93c974510e6
# 32948    9a7c6041fa9592d9d9ef6cfe62a71f8c
# 32949    83808703fc0706a22e264b9d75f04a2e
# 32950    106392145fca363410d287a815be6de4
# Name: product_id, Length: 32951, dtype: object>

# %%
products_df.groupby(by="product_category_name").product_id.nunique().sort_values(ascending=False)
# Out:
# product_category_name
# cama_mesa_banho                  3639
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# casa_conforto_2                     5
# fashion_roupa_infanto_juvenil       5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: product_id, Length: 73, dtype: int64

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='payment_type', data=order_payment_df, palette='viridis', hue='payment_type', legend=False)
plt.title('Jumlah Penggunaan Jenis Pembayaran')
plt.xlabel('Jenis Pembayaran')
plt.ylabel('Jumlah Pesanan')
plt.show()

# %% [markdown]
# ### Pertanyaan 2:

# %%
plt.figure(figsize=(16, 6))
sns.countplot(x='product_category_name', hue='product_category_name', data=products_df, palette='viridis', order=products_df['product_category_name'].value_counts().index, legend=False)
plt.title('Distribusi Penjualan Berdasarkan Kategori Produk')
plt.xlabel('Kategori Produk')
plt.ylabel('Jumlah Penjualan')
plt.xticks(rotation=70, ha='right')  
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1
# Dari grafik batang tentang jenis pembayaran, kita dapat melihat distribusi penggunaan jenis pembayaran. kita dapat menyimpulkan pembayaran menggunakan credit card paling banyak. Informasi ini dapat bermanfaat untuk pemahaman tentang perilaku pembayaran pelanggan.
# - Conclution pertanyaan 2
# Dari grafik batang (countplot) tentang jenis pembayaran, kita dapat melihat Distribusi Penjualan Berdasarkan Kategori Produk. kategori produk yang paling tinggi atau paling banyak diminati adalah cama messa banho.
